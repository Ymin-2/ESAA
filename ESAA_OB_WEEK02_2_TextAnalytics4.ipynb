# %% [markdown]
# <a href="https://colab.research.google.com/github/Ymin-2/ESAA/blob/main/ESAA_OB_WEEK02_2_TextAnalytics4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**문서 군집화 소개와 실습(Opinion Review 데이터 세트)**

# %% [markdown]
# **문서 군집화 개념**
#
# 문서 군집화: 비슷한 텍스트 구성의 문서를 군집화하는 것
# 문서 군집화는 학습 데이터 세트가 필요 없는 비지도학습 기반으로 동작함

# %% [markdown]
# **Opinion Review 데이터 세트를 이용한 문서 군집화 수행하기**
#
# 여러 개의 파일을 한 개의 DataFrame으로 로딩해 데이터 처리
# 해당 디렉터리 내에 있는 파일을 하나씩 읽어서 파일명과 파일 리뷰를 하나의 DataFrame으로 로드하여 파일명별로 어떤 리뷰를 담고 있는지 개략적으로 살펴보기
#
# 데이터를 로드할 절대 경로 디렉터리를 먼저 지정한 뒤, 이 위치에서 데이터 로딩

# %%
import pandas as pd
import glob, os
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 700)

from google.colab import drive
drive.mount('/content/drive')
path = r'/content /drive/MyDrive/ESAA/Data/topics'
# path로 지정한 디렉터리 밑에 있는 모든 .data 파일들의 파일명을 리스트로 취합
all_files = glob.glob(os.path.join(path,"*.data"))
filename_list = []
opinion_text = []

# 개별 파일들의 파일명은 filename_list 리스트로 취합
# 개별 파일들의 파일 내용은 DataFrame 로딩 후 다시 string으로 변환하여 opinion_text 리스트로 취합
for file_ in all_files:
  # 개별 파일을 읽어서 DataFrame으로 생성
  df = pd.read_table(file_, index_col=None, header=0, encoding='latin1')
  # 절대경로로 주어진 파일명을 가공.
  # 맨 마지막 .data 확장자도 제거
  filename_ = file_.split('/')[-1]
  filename = filename_.split('.')[0]

  # 파일명 리스트와 파일 내용 리스트에 파일명과 파일 내용을 추가
  filename_list.append(filename)
  opinion_text.append(df.to_string())

# 파일명 리스트와 파일 내용 리스트를 DataFrame으로 생성
document_df = pd.DataFrame({'filename':filename_list, 'opinion_text':opinion_text})
document_df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                       filename  \
# 0   free_bestwestern_hotel_sfo
# 1      staff_swissotel_chicago
# 2     price_holiday_inn_london
# 3  staff_bestwestern_hotel_sfo
# 4            features_windows7
#
# ...

# %% [markdown]
# 문서를 TF-IDF 형태로 피처 벡터화
#
# TfidfVectorizer는 Lemmatization 같은 어근 변환을 직접 지원하진 않지만, tokenizer 인자에 커스텀 어근 변환 함수를 적용해 어근 변환을 수행할 수 있음
# 이를 위해 LemNormalize() 함수를 만듦

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# 필수 NLTK 데이터 다운로드
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')

def LemNormalize(text):
  lemmatizer = WordNetLemmatizer()
  return [lemmatizer.lemmatize(token) for token in word_tokenize(text)]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect = TfidfVectorizer(tokenizer = LemNormalize, stop_words='english', \
                             ngram_range = (1, 2), min_df = 0.05, max_df = 0.85)

# opinion_text 칼럼값으로 feature vectorization 수행
feature_vect = tfidf_vect.fit_transform(document_df['opinion_text'])

# %% [markdown]
# 문서별 텍스트가 TF-IDF 변환된 피처 벡터화 행렬 데이터에 대해서 군집화를 수행해 어떤 문서끼리 군집되는지 확인
# 군집화 기법은 K-평균 적용

# %%
from sklearn.cluster import KMeans

# 5개 집합으로 군집화 수행. 예제를 위해 동일한 클러스터링 결과 도출용 random_state=0
km_cluster = KMeans(n_clusters=5, max_iter = 10000, random_state=0)
km_cluster.fit(feature_vect)
cluster_label = km_cluster.labels_
cluster_centers = km_cluster.cluster_centers_

# %% [markdown]
# 각 데이터별로 할당된 군집의 레이블을 파일명과 파일 내용을 가지고 있는 document_df DataFrame에 'cluster_label' 칼럼을 추가해 저장
# 군집이 각 주제별로 유사한 형태로 잘 구성됐는지 확인

# %%
document_df['cluster_label'] = cluster_label
document_df.head()
# Out:
#                       filename  \
# 0   free_bestwestern_hotel_sfo
# 1      staff_swissotel_chicago
# 2     price_holiday_inn_london
# 3  staff_bestwestern_hotel_sfo
# 4            features_windows7
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   opinion_text  \
# ...

# %% [markdown]
# 판다스 DataFrame의 sort_values(by=정렬칼럼명)를 수행하면 인자로 입력된 '정렬칼럼명'으로 데이터 정렬 가능

# %%
document_df[document_df['cluster_label']==0].sort_values(by='filename')
# Out:
#                        filename  \
# 6    battery-life_ipod_nano_8gb
# 27  battery-life_netbook_1005ha
# 5         buttons_amazon_kindle
# 24          sound_ipod_nano_8gb
# 44   speed_garmin_nuvi_255W_gps
# 23   voice_garmin_nuvi_255W_gps
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    opinion_text  \
# ...

# %%
document_df[document_df['cluster_label']==1].sort_values(by = 'filename')
# Out:
#                            filename  \
# 43       battery-life_amazon_kindle
# 45           food_swissotel_chicago
# 0        free_bestwestern_hotel_sfo
# 22    gas_mileage_toyota_camry_2007
# 10      location_holiday_inn_london
# 11        mileage_honda_accord_2008
# 7     performance_honda_accord_2008
# 2          price_holiday_inn_london
# 39        quality_toyota_camry_2007
# 28      rooms_bestwestern_hotel_sfo
# 33          rooms_swissotel_chicago
# 15   satellite_garmin_nuvi_255W_gps
# 9        service_holiday_inn_london
# 47  service_swissotel_hotel_chicago
# 14         size_asus_netbook_1005ha
# 1           staff_swissotel_chicago
# 37   transmission_toyota_camry_2007
#
# ...

# %%
document_df[document_df['cluster_label']==2].sort_values(by='filename')
# Out:
#                        filename  \
# 20   performance_netbook_1005ha
# 21          price_amazon_kindle
# 3   staff_bestwestern_hotel_sfo
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    opinion_text  \
# ...

# %%
document_df[document_df['cluster_label']==3].sort_values(by='filename')
# Out:
#                            filename  \
# 18        comfort_toyota_camry_2007
# 34  directions_garmin_nuvi_255W_gps
# 49       interior_honda_accord_2008
# 12       interior_toyota_camry_2007
# 31          keyboard_netbook_1005ha
# 41         navigation_amazon_kindle
# 42          room_holiday_inn_london
# 40    service_bestwestern_hotel_sfo
# 16     updates_garmin_nuvi_255W_gps
#
# ...

# %%
document_df[document_df['cluster_label']==4].sort_values(by='filename')
# Out:
#                           filename  \
# 8   bathroom_bestwestern_hotel_sfo
# 13       comfort_honda_accord_2008
# 32    display_garmin_nuvi_255W_gps
# 36   eyesight-issues_amazon_kindle
# 4                features_windows7
# 48             fonts_amazon_kindle
# 38         food_holiday_inn_london
# 35  location_bestwestern_hotel_sfo
# 46   parking_bestwestern_hotel_sfo
# 30     screen_garmin_nuvi_255W_gps
# 26            screen_ipod_nano_8gb
# 19           screen_netbook_1005ha
# 29         seats_honda_accord_2008
# 17                  speed_windows7
# 25             video_ipod_nano_8gb
#
# ...

# %%
# 중심 개수를 5개에서 3개로 낮춰서 3개 그룹으로 군집화한 뒤 결과 확인
from sklearn.cluster import KMeans

# 3개의 집합으로 군집화
km_cluster = KMeans(n_clusters=3, max_iter = 10000, random_state=0)
km_cluster.fit(feature_vect)
cluster_label = km_cluster.labels_

# 소속 클러스터를 cluster_label 칼럼으로 할당하고 cluster_label 값으로 정렬
document_df['cluster_label'] = cluster_label
document_df.sort_values(by='cluster_label')
# Out:
#                            filename  \
# 6        battery-life_ipod_nano_8gb
# 5             buttons_amazon_kindle
# 13        comfort_honda_accord_2008
# 29          seats_honda_accord_2008
# 24              sound_ipod_nano_8gb
# 26             screen_ipod_nano_8gb
# 23       voice_garmin_nuvi_255W_gps
# 19            screen_netbook_1005ha
# 27      battery-life_netbook_1005ha
# 44       speed_garmin_nuvi_255W_gps
# 42          room_holiday_inn_london
# 35   location_bestwestern_hotel_sfo
# 7     performance_honda_accord_2008
# 12       interior_toyota_camry_2007
# 14         size_asus_netbook_1005ha
# 0        free_bestwestern_hotel_sfo
# 31          keyboard_netbook_1005ha
# 28      rooms_bestwestern_hotel_sfo
# 22    gas_mileage_toyota_camry_2007
# 15   satellite_garmin_nuvi_255W_gps
# 10      location_holiday_inn_london
# 11        mileage_honda_accord_2008
# 18        comfort_toyota_camry_2007
# 47  service_swissotel_hotel_chicago
# 37   transmission_toyota_camry_2007
# ...

# %% [markdown]
# **군집별 핵심 단어 추출하기**

# %% [markdown]
# KMeans 객체는 각 군집을 구성하는 단어 피처가 군집의 중심(centroid)을 기준으로 얼마나 가깝게 위치해 있는지 clusters_centers_라는 속성으로 제공
#
# clusters_centers_: 배열 값으로 제공됨, 행은 개별 군집을, 열은 개별 피처를 의미
# 각 배열 내의 값은 개별 군집 내의 상대 위치를 숫자 값으로 표현한 일종의 좌표 값

# %%
# 군집 3개로 생성한 KMeans 객체인 km_cluster에서 cluster_centers_ 속성값을 가져온 뒤 값 확인
cluster_centers = km_cluster.cluster_centers_
print('cluster_centers shape:', cluster_centers.shape)
print(cluster_centers)
# Out:
# cluster_centers shape: (3, 6069)
# [[0.00228939 0.00105434 0.         ... 0.         0.         0.        ]
#  [0.         0.00029879 0.00065949 ... 0.00127969 0.00100976 0.00100976]
#  [0.00082175 0.00108437 0.         ... 0.         0.         0.        ]]

# %%
# 군집별 top n 핵심 단어, 그 단어의 중심 위치 상댓값, 대상 파일명을 반환함
def get_cluster_details(cluster_model, cluster_data, feature_names, clusters_num, top_n_features=10):
  cluster_details = {}

  # cluster_centers array의 값이 큰 순으로 정렬된 인덱스 값을 반환
  # 군집 중심점(centroid)별 할당된 word 피처들의 거리값이 큰 순으로 값을 구하기 위함.
  centroid_feature_ordered_ind = cluster_model.cluster_centers_.argsort()[:, ::-1]

  # 개별 군집별로 반복하면서 핵심 단어, 그 단어의 중심 위치 상댓값, 대상 파일명 입력
  for cluster_num in range(clusters_num):
    # 개별 군집별 정보를 담을 데이터 초기화
    cluster_details[cluster_num]={}
    cluster_details[cluster_num]['cluster'] = cluster_num

    # cluster_centers_.argsort()[:, ::-1]로 구한 인덱스를 이용해 top n 피처 단어를 구함
    top_feature_indexes = centroid_feature_ordered_ind[cluster_num, :top_n_features]
    top_features = [feature_names[ind] for ind in top_feature_indexes]

    # top_feature_indexes를 이용해 해당 피처 단어의 중심 위치 상댓값 구함
    top_feature_values = cluster_model.cluster_centers_[cluster_num, top_feature_indexes].tolist()

    # cluster_details 딕셔너리 객체에 기별 군집별 핵심단어와 중심위치 상댓값, 해당 파일명 입력
    cluster_details[cluster_num]['top_features'] = top_features
    cluster_details[cluster_num]['top_features_value'] = top_feature_values
    filenames = cluster_data[cluster_data['cluster_label'] == cluster_num]['filename']
    filenames = filenames.values.tolist()

    cluster_details[cluster_num]['filenames'] = filenames

  return cluster_details

# %% [markdown]
# get_cluster_details()를 호출하면 dictionary를 원소로 가지는 리트스인 cluster_details를 반환

# %%
def print_cluster_details(cluster_details):
  for cluster_num, cluster_detail in cluster_details.items():
    print('##### Cluster {0}'.format(cluster_num))
    print('Top features:', cluster_detail['top_features'])
    print('Reviews 파일명:', cluster_detail['filenames'][:7])
    print('==============================================')

# %%
feature_names = tfidf_vect.get_feature_names_out()

cluster_details = get_cluster_details(cluster_model = km_cluster, cluster_data = document_df,
                                      feature_names = feature_names, clusters_num = 3, top_n_features = 10)
print_cluster_details(cluster_details)
# Out:
# ##### Cluster 0
# Top features: ['screen', 'battery', 'keyboard', 'battery life', 'life', 'video', 'quality', 'button', 'size', 'sound']
# Reviews 파일명: ['buttons_amazon_kindle', 'battery-life_ipod_nano_8gb', 'comfort_honda_accord_2008', 'screen_netbook_1005ha', 'voice_garmin_nuvi_255W_gps', 'sound_ipod_nano_8gb', 'screen_ipod_nano_8gb']
# ...
# ##### Cluster 1
# Top features: ['room', 'hotel', 'service', 'staff', 'interior', 'food', 'location', 'seat', 'price', 'comfortable']
# Reviews 파일명: ['free_bestwestern_hotel_sfo', 'staff_swissotel_chicago', 'price_holiday_inn_london', 'performance_honda_accord_2008', 'service_holiday_inn_london', 'location_holiday_inn_london', 'mileage_honda_accord_2008']
# ...
# ##### Cluster 2
# Top features: ['performance', 'mileage', 'direction', 'map', 'speed', 'font', 'transmission', 'gas', 'satellite', 'gas mileage']
# ...
